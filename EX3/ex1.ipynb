# %%
from __future__ import print_function
from PIL import Image
import os
import os.path
import errno
import numpy as np
import sys
import zipfile
import scipy.io as sio
import torch.utils.data as data
import glob

class UCSD(data.Dataset):
    """UCSD pedestrian counting data."""

    def __init__(self, data_dir, annotation_dir, transform=None):

        self.file_list = []
        self.file_cnts = []
        
        files = glob.glob(
            os.path.join(
                annotation_dir, 
                '*count_roi_mainwalkway.mat'))
        
        for f in files:
            tmp = sio.loadmat(f)
            
            l_count = tmp['count'][0][0].ravel()
            r_count = tmp['count'][0][1].ravel()
            t_count = l_count + r_count
            
            [self.file_cnts.append(c) for c in t_count]
            
            file_parts = os.path.basename(f).split('_')
            seq_id = "_".join(file_parts[0:3])
            
            for i in np.arange(len(t_count)):
                
                self.file_list.append(
                    os.path.join(
                        data_dir,
                        seq_id + ".y",
                        "{}_f{:03d}.png".format(seq_id,i+1)))
            
            self.transform = transform

    def __len__(self):
        return len(self.file_list)
        
    def __getitem__(self, idx):
        img_name = os.path.join(self.file_list[idx])
        img = Image.open(img_name)
        img = img.resize((128,128))

        if self.transform:
            img = self.transform(img)
        return img, self.file_cnts[idx]

# %%
import torch
import random

class SubsetSampler(object):

    def __init__(self, subset):
        self.subset = subset

    def __iter__(self):
        return iter(self.subset)

    def __len__(self):
        return len(self.subset)


class RandomSubsetSampler(object):

    def __init__(self, data_source, train_share=0.8):

        # Generate a list of indizes reaching from 0 ... len(data_source)-1
        idxList = list(range(0,len(data_source)))

        # Ensure that list is sorted randomly
        random.shuffle(idxList)

        # Split dataset random shares of train and test data
        numberOfTrainSamples = int(len(data_source) / (1 / train_share))
        
        self.train_samples = idxList[:numberOfTrainSamples]
        self.test_samples = idxList[numberOfTrainSamples:]


    def trainSampler(self):
        return SubsetSampler(self.train_samples)

    def testSampler(self):
        return SubsetSampler(self.test_samples)

# %%
import numpy as np
import torch

# Converts the 1-channel image into a 3-channel mage
class ExpandTo3D(object):

    def __call__(self, image):

        width = image.size()[1]
        height = image.size()[2]

        return image.expand(3,width,height)

# %%
import torch
import torchvision.transforms as transforms
from torch.autograd import Variable
import torch.optim as optim
import torch.nn as nn
import torchvision.datasets
import torchvision.models as models


transformsData = transforms.Compose([transforms.Scale(250), transforms.ToTensor(), ExpandTo3D()] )

dataset = UCSD(data_dir='./data/ucsdpeds/vidf', annotation_dir='./data/vidf-cvpr', transform=transformsData)

sampler = RandomSubsetSampler(dataset)

trainloader = torch.utils.data.DataLoader(dataset, batch_size=20, sampler=sampler.trainSampler(), num_workers=2 )
testloader = torch.utils.data.DataLoader(dataset, batch_size=20, sampler=sampler.testSampler(), num_workers=2)

net = models.alexnet(num_classes=60)
net.cuda()

# Alternative: Mean Squared Error
# Alternative: Use ADAM
# Learning Rate 1/2 after every 50 epoch
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.01, momentum=0.9)

print("Start training")
for epoch in range(300):
    
    running_loss = 0.0
    for data in trainloader:
        # get the inputs
        inputs, labels = data
        labels = labels.long()
        
        inputs = inputs.cuda()
        labels = labels.cuda()
  
        # wrap them in Variable
        inputs, labels = Variable(inputs), Variable(labels)

        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        outputs = net(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()


    print( str(epoch) + ": " + str(loss.data[0]))

    correct = 0
    total = 0
    
    for data in testloader:
  
        inputs, labels = data
        labels = labels.long()
        
        inputs = inputs.cuda()
        labels = labels.cuda()
        
        outputs = net(Variable(inputs))
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum()
        
    print('Accuracy of the network on the test images: %f %%' % (100 * correct / total))

print('Finished Training')
# Out:
# Start training
# 0: 3.7887134552001953
# Accuracy of the network on the test images: 9.500000 %
# 1: 3.537203550338745
# Accuracy of the network on the test images: 6.250000 %
# 2: 3.5200493335723877
# Accuracy of the network on the test images: 7.500000 %
# 3: 3.5156090259552
# Accuracy of the network on the test images: 7.000000 %
# 4: 3.549427032470703
# Accuracy of the network on the test images: 6.000000 %
# 5: 3.5307552814483643
# Accuracy of the network on the test images: 4.500000 %
# 6: 3.551217555999756
# Accuracy of the network on the test images: 4.000000 %
# 7: 3.530918836593628
# Accuracy of the network on the test images: 3.750000 %
# 8: 3.5493812561035156
# Accuracy of the network on the test images: 3.750000 %
# 9: 3.528485059738159
# Accuracy of the network on the test images: 3.750000 %
# 10: 3.521488666534424
# Accuracy of the network on the test images: 3.750000 %
# 11: 3.501631498336792
# Accuracy of the network on the test images: 3.750000 %
# 12: 3.471083402633667
# Accuracy of the network on the test images: 4.000000 %
# 13: 3.405179500579834
# Accuracy of the network on the test images: 10.250000 %
# 14: 3.267322540283203
# Accuracy of the network on the test images: 3.750000 %
# 15: 3.3077614307403564
# Accuracy of the network on the test images: 11.000000 %
# 16: 2.5754294395446777
# Accuracy of the network on the test images: 23.500000 %
# 17: 2.2317099571228027
# Accuracy of the network on the test images: 25.750000 %
# 18: 1.7556164264678955
# Accuracy of the network on the test images: 31.250000 %
# 19: 1.802239179611206
# Accuracy of the network on the test images: 45.000000 %
# 20: 1.747198462486267
# Accuracy of the network on the test images: 48.000000 %
# 21: 1.7308849096298218
# Accuracy of the network on the test images: 49.250000 %
# 22: 1.2372424602508545
# Accuracy of the network on the test images: 53.250000 %
# 23: 1.600780725479126
# Accuracy of the network on the test images: 59.750000 %
# 24: 1.2022640705108643
# Accuracy of the network on the test images: 58.500000 %
# 25: 1.3198575973510742
# Accuracy of the network on the test images: 58.250000 %
# 26: 1.174354910850525
# Accuracy of the network on the test images: 56.250000 %
# 27: 1.3949806690216064
# Accuracy of the network on the test images: 63.750000 %
# 28: 0.9176952242851257
# Accuracy of the network on the test images: 58.250000 %
# 29: 0.8865889310836792
# Accuracy of the network on the test images: 65.250000 %
# 30: 1.1020787954330444
# Accuracy of the network on the test images: 69.250000 %
# 31: 0.5373495817184448
# Accuracy of the network on the test images: 69.000000 %
# 32: 0.9529495239257812
# Accuracy of the network on the test images: 70.000000 %
# 33: 1.1322729587554932
# Accuracy of the network on the test images: 68.250000 %
# 34: 0.5121616125106812
# Accuracy of the network on the test images: 72.750000 %
# 35: 0.8116012811660767
# Accuracy of the network on the test images: 68.500000 %
# 36: 0.48511067032814026
# Accuracy of the network on the test images: 74.250000 %
# 37: 0.5496849417686462
# Accuracy of the network on the test images: 67.750000 %
# 38: 0.47131267189979553
# Accuracy of the network on the test images: 74.750000 %
# 39: 0.6927822828292847
# Accuracy of the network on the test images: 75.000000 %
# 40: 0.6352414488792419
# Accuracy of the network on the test images: 68.500000 %
# 41: 0.678429365158081
# Accuracy of the network on the test images: 74.500000 %
# 42: 0.7287197113037109
# Accuracy of the network on the test images: 77.750000 %
# 43: 0.41131967306137085
# Accuracy of the network on the test images: 76.750000 %
# 44: 0.35387396812438965
# Accuracy of the network on the test images: 73.250000 %
# 45: 0.7478238344192505
# Accuracy of the network on the test images: 74.500000 %
# 46: 0.6359387040138245
# Accuracy of the network on the test images: 73.250000 %
# 47: 0.5867472887039185
# Accuracy of the network on the test images: 75.000000 %
# 48: 0.42056816816329956
# Accuracy of the network on the test images: 78.000000 %
# 49: 0.5388429164886475
# Accuracy of the network on the test images: 75.250000 %
# 50: 0.42289167642593384
# Accuracy of the network on the test images: 79.250000 %
# 51: 0.29051169753074646
# Accuracy of the network on the test images: 73.500000 %
# 52: 0.6971733570098877
# Accuracy of the network on the test images: 78.750000 %
# 53: 0.27314162254333496
# Accuracy of the network on the test images: 80.250000 %
# 54: 0.4193461537361145
# Accuracy of the network on the test images: 76.250000 %
# 55: 0.2781670391559601
# Accuracy of the network on the test images: 78.000000 %
# 56: 0.18770985305309296
# Accuracy of the network on the test images: 75.250000 %
# 57: 0.2038276195526123
# Accuracy of the network on the test images: 83.000000 %
# 58: 0.7217114567756653
# Accuracy of the network on the test images: 74.500000 %
# 59: 0.0729818344116211
# Accuracy of the network on the test images: 78.750000 %
# 60: 0.5422601699829102
# Accuracy of the network on the test images: 72.750000 %
# 61: 0.4516497254371643
# Accuracy of the network on the test images: 79.750000 %
# 62: 0.27214115858078003
# Accuracy of the network on the test images: 79.750000 %
# 63: 0.3870740830898285
# Accuracy of the network on the test images: 77.250000 %
# 64: 0.3089653551578522
# Accuracy of the network on the test images: 80.000000 %
# 65: 0.24188849329948425
# Accuracy of the network on the test images: 76.250000 %
# 66: 0.22538837790489197
# Accuracy of the network on the test images: 82.250000 %
# 67: 0.2431546151638031
# Accuracy of the network on the test images: 81.500000 %
# 68: 0.1578342467546463
# Accuracy of the network on the test images: 80.000000 %
# 69: 0.35647931694984436
# Accuracy of the network on the test images: 81.750000 %
# 70: 0.8025190234184265
# Accuracy of the network on the test images: 82.250000 %
# 71: 0.24528613686561584
# Accuracy of the network on the test images: 80.750000 %
# 72: 0.16500191390514374
# Accuracy of the network on the test images: 81.000000 %
# 73: 0.18708114326000214
# Accuracy of the network on the test images: 84.000000 %
# 74: 0.01033406239002943
# Accuracy of the network on the test images: 85.000000 %
# 75: 0.3831424117088318
# Accuracy of the network on the test images: 82.000000 %
# 76: 0.023508548736572266
# Accuracy of the network on the test images: 85.250000 %
# 77: 0.09710879623889923
# Accuracy of the network on the test images: 82.750000 %
# 78: 0.1850634515285492
# Accuracy of the network on the test images: 82.500000 %
# 79: 0.1562587320804596
# Accuracy of the network on the test images: 82.000000 %
# 80: 0.280752032995224
# Accuracy of the network on the test images: 80.250000 %
# 81: 0.043650247156620026
# Accuracy of the network on the test images: 81.750000 %
# 82: 0.4318597912788391
# Accuracy of the network on the test images: 79.500000 %
# 83: 0.1392372101545334
# Accuracy of the network on the test images: 81.500000 %
# 84: 0.39633908867836
# Accuracy of the network on the test images: 80.500000 %
# 85: 0.34729355573654175
# Accuracy of the network on the test images: 83.250000 %
# 86: 0.2356555014848709
# Accuracy of the network on the test images: 83.250000 %
# 87: 0.319657564163208
# Accuracy of the network on the test images: 81.000000 %
# 88: 0.021373748779296875
# Accuracy of the network on the test images: 82.750000 %
# 89: 0.02349691465497017
# Accuracy of the network on the test images: 82.250000 %
# 90: 0.052667856216430664
# Accuracy of the network on the test images: 83.750000 %
# 91: 0.13569316267967224
# Accuracy of the network on the test images: 82.000000 %
# 92: 0.051740169525146484
# Accuracy of the network on the test images: 82.000000 %
# 93: 0.10557346045970917
# Accuracy of the network on the test images: 82.500000 %
# 94: 0.04140956327319145
# Accuracy of the network on the test images: 80.000000 %
# 95: 0.3947595953941345
# Accuracy of the network on the test images: 81.500000 %
# 96: 0.009564685635268688
# Accuracy of the network on the test images: 81.750000 %
# 97: 0.2162163257598877
# Accuracy of the network on the test images: 83.250000 %
# 98: 0.0026324272621423006
# Accuracy of the network on the test images: 84.500000 %
# 99: 0.0023631094954907894
# Accuracy of the network on the test images: 84.000000 %
# 100: 0.02763509750366211
# Accuracy of the network on the test images: 81.000000 %
# 101: 0.0918365940451622
# Accuracy of the network on the test images: 84.500000 %
# 102: 0.0481170192360878
# Accuracy of the network on the test images: 86.500000 %
# 103: 0.01040792465209961
# Accuracy of the network on the test images: 83.750000 %
# 104: 0.0712505355477333
# Accuracy of the network on the test images: 82.750000 %
# 105: 0.0012737751239910722
# Accuracy of the network on the test images: 85.500000 %
# 106: 0.005825900938361883
# Accuracy of the network on the test images: 82.500000 %
# 107: 0.008779382333159447
# Accuracy of the network on the test images: 85.000000 %
# 108: 0.013592338189482689
# Accuracy of the network on the test images: 82.750000 %
# 109: 0.05955486372113228
# Accuracy of the network on the test images: 82.000000 %
# 110: 0.05223972722887993
# Accuracy of the network on the test images: 83.250000 %
# 111: 0.0003775596560444683
# Accuracy of the network on the test images: 84.500000 %
# 112: 0.5499049425125122
# Accuracy of the network on the test images: 82.000000 %
# 113: 0.0929202288389206
# Accuracy of the network on the test images: 82.750000 %
# 114: 0.17140457034111023
# Accuracy of the network on the test images: 83.500000 %
# 115: 0.0025904655922204256
# Accuracy of the network on the test images: 84.500000 %
# 116: 0.004923820495605469
# Accuracy of the network on the test images: 84.750000 %
# 117: 0.013465071097016335
# Accuracy of the network on the test images: 84.750000 %
# 118: 0.16723227500915527
# Accuracy of the network on the test images: 85.250000 %
# 119: 0.03531203418970108
# Accuracy of the network on the test images: 83.500000 %
# 120: 0.08907463401556015
# Accuracy of the network on the test images: 84.250000 %
# 121: 0.05544481426477432
# Accuracy of the network on the test images: 84.500000 %
# 122: 0.09756536781787872
# Accuracy of the network on the test images: 84.250000 %
# 123: 0.005129575729370117
# Accuracy of the network on the test images: 85.750000 %
# 124: 0.008039569482207298
# Accuracy of the network on the test images: 84.000000 %
# 125: 0.07157035171985626
# Accuracy of the network on the test images: 83.250000 %
# 126: 0.12218451499938965
# Accuracy of the network on the test images: 84.000000 %
# 127: 0.6717990636825562
# Accuracy of the network on the test images: 78.000000 %
# 128: 0.03280582278966904
# Accuracy of the network on the test images: 84.500000 %
# 129: 0.013153386302292347
# Accuracy of the network on the test images: 80.500000 %
# 130: 0.08935417979955673
# Accuracy of the network on the test images: 84.250000 %
# 131: 0.020158911123871803
# Accuracy of the network on the test images: 83.250000 %
# 132: 0.04473619535565376
# Accuracy of the network on the test images: 84.000000 %
# 133: 0.10623650252819061
# Accuracy of the network on the test images: 84.250000 %
# 134: 0.0018910884391516447
# Accuracy of the network on the test images: 82.750000 %
# 135: 0.020634938031435013
# Accuracy of the network on the test images: 82.750000 %
# 136: 0.0465255007147789
# Accuracy of the network on the test images: 85.250000 %
# 137: 0.06965599209070206
# Accuracy of the network on the test images: 84.000000 %
# 138: 0.18613433837890625
# Accuracy of the network on the test images: 82.000000 %
# 139: 0.06469793617725372
# Accuracy of the network on the test images: 81.500000 %
# 140: 0.01033487357199192
# Accuracy of the network on the test images: 84.750000 %
# 141: 0.11158857494592667
# Accuracy of the network on the test images: 83.000000 %
# 142: 0.0016274452209472656
# Accuracy of the network on the test images: 84.500000 %
# 143: 0.33712801337242126
# Accuracy of the network on the test images: 84.500000 %
# 144: 0.021590661257505417
# Accuracy of the network on the test images: 81.250000 %
# 145: 0.3275933861732483
# Accuracy of the network on the test images: 84.500000 %
# 146: 0.004598522093147039
# Accuracy of the network on the test images: 85.750000 %
# 147: 0.04191136360168457
# Accuracy of the network on the test images: 81.250000 %
# 148: 0.008802366442978382
# Accuracy of the network on the test images: 84.500000 %
# 149: 0.00640792865306139
# Accuracy of the network on the test images: 84.500000 %
# 150: 0.0021589279640465975
# Accuracy of the network on the test images: 86.500000 %
# 151: 0.00014905929856467992
# Accuracy of the network on the test images: 85.750000 %
# 152: 0.0011233330005779862
# Accuracy of the network on the test images: 82.500000 %
# 153: 0.00019073486328125
# Accuracy of the network on the test images: 84.250000 %
# 154: 0.0007512092706747353
# Accuracy of the network on the test images: 83.750000 %
# 155: 0.0003982066991738975
# Accuracy of the network on the test images: 84.500000 %
# 156: 0.00033311842707917094
# Accuracy of the network on the test images: 79.250000 %
# 157: 2.403259350103326e-05
# Accuracy of the network on the test images: 85.500000 %
# 158: 0.00034842491731978953
# Accuracy of the network on the test images: 84.250000 %
# 159: 0.0001750946103129536
# Accuracy of the network on the test images: 83.250000 %
# 160: 0.0025865554343909025
# Accuracy of the network on the test images: 84.250000 %
# 161: 0.00154285435564816
# Accuracy of the network on the test images: 83.250000 %
# 162: 0.011900663375854492
# Accuracy of the network on the test images: 83.250000 %
# 163: 0.0038722038734704256
# Accuracy of the network on the test images: 81.500000 %
# 164: 0.0023800849448889494
# Accuracy of the network on the test images: 83.500000 %
# 165: 0.08336076885461807
# Accuracy of the network on the test images: 82.250000 %
# 166: 0.0012330531608313322
# Accuracy of the network on the test images: 83.750000 %
# 167: 0.0002096176176564768
# Accuracy of the network on the test images: 83.750000 %
# 168: 0.0003307819424662739
# Accuracy of the network on the test images: 83.750000 %
# 169: 6.818771362304688e-05
# Accuracy of the network on the test images: 82.250000 %
# 170: 1.449584942747606e-05
# Accuracy of the network on the test images: 83.500000 %
# 171: 0.0024814605712890625
# Accuracy of the network on the test images: 83.750000 %
# 172: 0.0021467208862304688
# Accuracy of the network on the test images: 84.250000 %
# 173: 0.4572536051273346
# Accuracy of the network on the test images: 83.000000 %
# 174: 0.01971902884542942
# Accuracy of the network on the test images: 82.250000 %
# 175: 0.03856835514307022
# Accuracy of the network on the test images: 83.000000 %
# 176: 0.00160808558575809
# Accuracy of the network on the test images: 81.250000 %
# 177: 8.831024024402723e-05
# Accuracy of the network on the test images: 84.000000 %
# 178: 0.00020895004854537547
# Accuracy of the network on the test images: 83.250000 %
# 179: 0.0005127906915731728
# Accuracy of the network on the test images: 84.250000 %
# 180: 0.0003723144473042339
# Accuracy of the network on the test images: 83.000000 %
# 181: 0.00020503997802734375
# Accuracy of the network on the test images: 82.250000 %
# 182: 0.013815069571137428
# Accuracy of the network on the test images: 84.500000 %
# 183: 0.0037107467651367188
# Accuracy of the network on the test images: 83.000000 %
# 184: 0.0028286934830248356
# Accuracy of the network on the test images: 82.500000 %
# 185: 0.00019388199143577367
# Accuracy of the network on the test images: 83.000000 %
# 186: 0.1064995750784874
# Accuracy of the network on the test images: 79.500000 %
# 187: 0.0015274047618731856
# Accuracy of the network on the test images: 84.250000 %
# 188: 0.0031834125984460115
# Accuracy of the network on the test images: 81.500000 %
# 189: 0.017177676782011986
# Accuracy of the network on the test images: 82.750000 %
# 190: 0.001580953598022461
# Accuracy of the network on the test images: 80.500000 %
# 191: 0.002025127410888672
# Accuracy of the network on the test images: 86.000000 %
# 192: 0.00037364958552643657
# Accuracy of the network on the test images: 85.750000 %
# 193: 0.031133126467466354
# Accuracy of the network on the test images: 82.750000 %
# 194: 0.0001203536958200857
# Accuracy of the network on the test images: 86.250000 %
# 195: 0.0005696296575479209
# Accuracy of the network on the test images: 84.500000 %
# 196: 4.940032886224799e-05
# Accuracy of the network on the test images: 82.500000 %
# 197: 0.004732942674309015
# Accuracy of the network on the test images: 81.500000 %
# 198: 0.0008528232574462891
# Accuracy of the network on the test images: 83.250000 %
# 199: 0.0029574870131909847
# Accuracy of the network on the test images: 85.750000 %
# 200: 0.0022188187576830387
# Accuracy of the network on the test images: 85.250000 %
# 201: 0.015810441225767136
# Accuracy of the network on the test images: 86.000000 %
# 202: 0.00031490327091887593
# Accuracy of the network on the test images: 85.000000 %
# 203: 0.027135610580444336
# Accuracy of the network on the test images: 84.250000 %
# 204: 1.3828277587890625e-05
# Accuracy of the network on the test images: 85.250000 %
# 205: 8.134842209983617e-05
# Accuracy of the network on the test images: 85.500000 %
# 206: 1.3256072634248994e-05
# Accuracy of the network on the test images: 84.000000 %
# 207: 0.00032939910306595266
# Accuracy of the network on the test images: 85.000000 %
# 208: 1.2874603271484375e-05
# Accuracy of the network on the test images: 86.000000 %
# 209: 3.013610876223538e-05
# Accuracy of the network on the test images: 85.750000 %
# 210: 0.00015459061251021922
# Accuracy of the network on the test images: 86.500000 %
# 211: 0.00040683746919967234
# Accuracy of the network on the test images: 85.500000 %
# 212: 0.00045909881009720266
# Accuracy of the network on the test images: 86.750000 %
# 213: 2.937316821771674e-05
# Accuracy of the network on the test images: 86.500000 %
# 214: 0.00012602805509231985
# Accuracy of the network on the test images: 84.250000 %
# 215: 0.0010105610126629472
# Accuracy of the network on the test images: 83.500000 %
# 216: 7.152557373046875e-06
# Accuracy of the network on the test images: 85.000000 %
# 217: 1.8215179807157256e-05
# Accuracy of the network on the test images: 84.750000 %
# 218: 2.670288040462765e-06
# Accuracy of the network on the test images: 85.000000 %
# 219: 2.2029877072782256e-05
# Accuracy of the network on the test images: 86.500000 %
# 220: 6.008148375258315e-06
# Accuracy of the network on the test images: 85.000000 %
# 221: 0.00011539459228515625
# Accuracy of the network on the test images: 84.750000 %
# 222: 0.0032227516639977694
# Accuracy of the network on the test images: 81.750000 %
# 223: 2.517700158932712e-05
# Accuracy of the network on the test images: 83.250000 %
# 224: 0.011860656552016735
# Accuracy of the network on the test images: 84.000000 %
# 225: 0.13215240836143494
# Accuracy of the network on the test images: 82.250000 %
# 226: 0.06020154803991318
# Accuracy of the network on the test images: 84.750000 %
# 227: 0.24398450553417206
# Accuracy of the network on the test images: 83.750000 %
# 228: 0.0014887333381921053
# Accuracy of the network on the test images: 82.750000 %
# 229: 0.001825046492740512
# Accuracy of the network on the test images: 86.250000 %
# 230: 0.0008139133569784462
# Accuracy of the network on the test images: 86.250000 %
# 231: 0.0003391265927348286
# Accuracy of the network on the test images: 84.000000 %
# 232: 0.010836124420166016
# Accuracy of the network on the test images: 86.250000 %
# 233: 0.0013221740955486894
# Accuracy of the network on the test images: 84.750000 %
# 234: 0.021126508712768555
# Accuracy of the network on the test images: 81.000000 %
# 235: 0.021063685417175293
# Accuracy of the network on the test images: 83.750000 %
# 236: 0.008247947320342064
# Accuracy of the network on the test images: 84.250000 %
# 237: 0.0001088142380467616
# Accuracy of the network on the test images: 84.750000 %
# 238: 0.0309632308781147
# Accuracy of the network on the test images: 83.250000 %
# 239: 0.02435297891497612
# Accuracy of the network on the test images: 84.000000 %
# 240: 0.002132415771484375
# Accuracy of the network on the test images: 84.000000 %
# 241: 0.00033512114896439016
# Accuracy of the network on the test images: 85.750000 %
# 242: 0.004244041629135609
# Accuracy of the network on the test images: 84.000000 %
# 243: 0.00031213759211823344
# Accuracy of the network on the test images: 84.250000 %
# 244: 0.0006612777942791581
# Accuracy of the network on the test images: 85.250000 %
# 245: 0.007459068205207586
# Accuracy of the network on the test images: 85.000000 %
# 246: 1.3498022556304932
# Accuracy of the network on the test images: 82.750000 %
# 247: 0.14361628890037537
# Accuracy of the network on the test images: 85.250000 %
# 248: 0.27361178398132324
# Accuracy of the network on the test images: 84.750000 %
# 249: 0.00046520231990143657
# Accuracy of the network on the test images: 85.250000 %
# 250: 0.005107259843498468
# Accuracy of the network on the test images: 84.750000 %
# 251: 0.0002157211274607107
# Accuracy of the network on the test images: 84.750000 %
# 252: 0.0011539459228515625
# Accuracy of the network on the test images: 83.500000 %
# 253: 0.00014562606520485133
# Accuracy of the network on the test images: 84.250000 %
# 254: 0.00022010803513694555
# Accuracy of the network on the test images: 84.250000 %
# 255: 0.0002346038818359375
# Accuracy of the network on the test images: 85.250000 %
# 256: 0.0040090084075927734
# Accuracy of the network on the test images: 84.000000 %
# 257: 0.05696415901184082
# Accuracy of the network on the test images: 85.000000 %
# 258: 0.25386732816696167
# Accuracy of the network on the test images: 84.750000 %
# 259: 0.0009564399952068925
# Accuracy of the network on the test images: 83.000000 %
# 260: 0.006100177764892578
# Accuracy of the network on the test images: 84.750000 %
# 261: 1.1539459592313506e-05
# Accuracy of the network on the test images: 83.500000 %
# 262: 0.007734823040664196
# Accuracy of the network on the test images: 85.000000 %
# 263: 0.0001104354887502268
# Accuracy of the network on the test images: 85.250000 %
# 264: 7.99179106252268e-05
# Accuracy of the network on the test images: 85.250000 %
# 265: 0.0007518291240558028
# Accuracy of the network on the test images: 82.750000 %
# 266: 0.0010769844520837069
# Accuracy of the network on the test images: 82.750000 %
# 267: 0.07464034855365753
# Accuracy of the network on the test images: 84.750000 %
# 268: 0.0014366150135174394
# Accuracy of the network on the test images: 84.500000 %
# 269: 3.719329833984375e-05
# Accuracy of the network on the test images: 84.500000 %
# 270: 3.1757354008732364e-05
# Accuracy of the network on the test images: 86.500000 %
# 271: 0.0006100654718466103
# Accuracy of the network on the test images: 84.500000 %
# 272: 8.392333984375e-05
# Accuracy of the network on the test images: 85.000000 %
# 273: 0.0002749919949565083
# Accuracy of the network on the test images: 83.500000 %
# 274: 2.28881845032447e-06
# Accuracy of the network on the test images: 84.250000 %
# 275: 3.2138825190486386e-05
# Accuracy of the network on the test images: 84.250000 %
# 276: 3.280639793956652e-05
# Accuracy of the network on the test images: 86.250000 %
# 277: 0.0007192611810751259
# Accuracy of the network on the test images: 84.750000 %
# 278: 1.6307831174344756e-05
# Accuracy of the network on the test images: 84.750000 %
# 279: 0.00020885467529296875
# Accuracy of the network on the test images: 84.000000 %
# 280: 9.5367431640625e-07
# Accuracy of the network on the test images: 84.250000 %
# 281: 0.13370151817798615
# Accuracy of the network on the test images: 84.750000 %
# 282: 0.015770530328154564
# Accuracy of the network on the test images: 81.750000 %
# 283: 0.0021936893463134766
# Accuracy of the network on the test images: 81.250000 %
# 284: 0.007278537843376398
# Accuracy of the network on the test images: 80.000000 %
# 285: 0.10472273826599121
# Accuracy of the network on the test images: 83.250000 %
# 286: 0.0017396926414221525
# Accuracy of the network on the test images: 84.000000 %
# 287: 0.0010407924419268966
# Accuracy of the network on the test images: 81.750000 %
# 288: 0.0032292366959154606
# Accuracy of the network on the test images: 86.750000 %
# 289: 0.018224621191620827
# Accuracy of the network on the test images: 83.250000 %
# 290: 0.02152862586081028
# Accuracy of the network on the test images: 84.000000 %
# 291: 0.018243933096528053
# Accuracy of the network on the test images: 86.250000 %
# 292: 0.0003434181271586567
# Accuracy of the network on the test images: 86.750000 %
# 293: 0.001033782958984375
# Accuracy of the network on the test images: 84.750000 %
# 294: 6.771087646484375e-05
# Accuracy of the network on the test images: 85.750000 %
# 295: 0.0005807876586914062
# Accuracy of the network on the test images: 86.000000 %
# 296: 0.0002871036413125694
# Accuracy of the network on the test images: 84.250000 %
# 297: 1.3828277587890625e-05
# Accuracy of the network on the test images: 85.500000 %
# 298: 0.0004570007440634072
# Accuracy of the network on the test images: 84.500000 %
# 299: 0.001355934189632535
# Accuracy of the network on the test images: 86.750000 %
# Finished Training
